# %%
import cv2
import os
import matplotlib.pyplot as plt

# %%
root_path = "../CFIL_for_NIP/train_data/20250312_demo/"
task_name = "persam_f_mask_image_only"
folder_path = os.path.join(root_path, task_name, "test/20250312")

output_path = os.path.join(folder_path, "eval")
if not os.path.exists(output_path):
    os.makedirs(output_path)

files = os.listdir(folder_path)
N = 30

initial_image = cv2.imread(os.path.join(root_path, "initial_image.jpg"))
initial_image = cv2.cvtColor(initial_image, cv2.COLOR_BGR2RGB)

for i in range(N):
    file = files[i]
    input_image_path = os.path.join(folder_path, f"{i:04d}_input_image.jpg")
    output_image_path = os.path.join(folder_path, f"{i:04d}_output_image.jpg")
    if not os.path.exists(input_image_path):
        break

    input_image = cv2.imread(input_image_path)
    input_image = cv2.cvtColor(input_image, cv2.COLOR_BGR2RGB)
    
    output_image = cv2.imread(output_image_path)
    output_image = cv2.cvtColor(output_image, cv2.COLOR_BGR2RGB)

    fig = plt.figure()
    fig.add_subplot(1,3,1).set_title(str("bottleneck"))
    plt.imshow(initial_image)
    plt.axis('off')

    fig.add_subplot(1,3,2).set_title(str("input"))
    plt.imshow(input_image)
    plt.axis('off')

    fig.add_subplot(1,3,3).set_title(str("output"))
    plt.imshow(output_image)
    plt.axis('off')

    plt.show()
    plt.savefig(os.path.join(output_path, f"{i:04d}_eval_image.jpg"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 42
#      39 plt.axis('off')
#      41 plt.show()
# ---> 42 plt.imsave(os.path.join(output_path, f"{i:04d}_eval_image.jpg"))
#
# TypeError: imsave() missing 1 required positional argument: 'arr'
